# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2 as cv

import os
dir_path = 'D:\Cosmas\Desktop\CroqeeStuff\Croqee-app\server_python'

# %% [markdown]
# First loading two images:

# %%
base_img = np.array(Image.open(dir_path + '/test_images/shapes_1_draw_1.png'))
test_image_paths = [dir_path + '/test_images/shapes_1_draw_{}.png'.format(i) for i in range(1, 11)]
test_imgs = [np.array(Image.open(x))[:,:,:3] for x in test_image_paths]

# %%
plt.figure(figsize=(16,10))
plt.subplot(3,4,1)
plt.imshow(base_img)
for k, img in enumerate(test_imgs):
    plt.subplot(3,4,k+2)
    plt.imshow(img)

# %%
from alignImages import alignImages

# %%
aligned_imgs = [alignImages(img, base_img) for img in test_imgs]

# %%
plt.figure(figsize=(16,10))
plt.subplot(3,4,1)
plt.imshow(base_img)
for k, img in enumerate(test_imgs):
    plt.subplot(3,4,k+2)
    plt.imshow((img*0.5+0.5*base_img).astype(np.uint8))

# %%
plt.figure(figsize=(16,10))
for k, img in enumerate(aligned_imgs):
    img1 = np.any(base_img>100, axis=2)
    img2 = img>100
    assert np.any(np.logical_not(img1)) and np.any(np.logical_not(img2))
    
    dst1 = cv2.distanceTransform(img1.astype(np.uint8), cv.DIST_L2, 3)
    dst2 = cv2.distanceTransform(img2.astype(np.uint8), cv.DIST_L2, 3)
    
    mean_distance1 = np.sum(dst1 * np.logical_not(img2))/np.sum(np.logical_not(img2))
    mean_distance2 = np.sum(dst2 * np.logical_not(img1))/np.sum(np.logical_not(img1))
    
    #print(mean_distance1)
    #print(mean_distance1)
    plt.subplot(3,4,k+1, title='{} \n {}'.format(mean_distance1, mean_distance2))
    plt.imshow((img2*0.5+0.5*img1).astype(np.uint8))

# %%
def compute_distance_score(img1, img2):
    img1 = np.any(base_img>100, axis=2)
    img2 = img>100
    if not (np.any(np.logical_not(img1)) and np.any(np.logical_not(img2))):
        return 0
    
    dst1 = cv2.distanceTransform(img1.astype(np.uint8), cv.DIST_L2, 3)
    dst2 = cv2.distanceTransform(img2.astype(np.uint8), cv.DIST_L2, 3)
    
    mean_distance1 = np.sum(dst1 * np.logical_not(img2))/np.sum(np.logical_not(img2))
    mean_distance2 = np.sum(dst2 * np.logical_not(img1))/np.sum(np.logical_not(img1))
    
    summed_distance = mean_distance1 + mean_distance2
    
    min_dist, max_dist = 5, 40
    
    clipped_distance = np.clip(summed_distance, min_dist, max_dist)
    
    score = (clipped_distance - min_dist) / (max_dist - min_dist)
    score = (1 - score) * 100
    
    return int(score)

# %%
plt.figure(figsize=(16,10))
for k, img in enumerate(aligned_imgs):
    score = compute_distance_score(base_img, img)
    plt.subplot(3,4,k+1, title='score: {}'.format(score))
    plt.imshow((base_img[:, : ,0]*0.5+0.5*img).astype(np.uint8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-1b949b29ddcd> in <module>
#       3     score = compute_distance_score(base_img, img)
#       4     plt.subplot(3,4,k+1, title='score: {}'.format(score))
# ----> 5     plt.imshow((base_img*0.5+0.5*img).astype(np.uint8))
#
# ValueError: operands could not be broadcast together with shapes (600,800,3) (600,800)
